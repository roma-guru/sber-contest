# %%
# /media/artiom/Terminator/datasets/rucorpora_rusvectores/ruscorpora_mean_hs.model.bin

import gensim
# import modules and set up logging
from gensim.models import word2vec
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# load up unzipped corpus from http://mattmahoney.net/dc/text8.zip
sentences = word2vec.Text8Corpus('/media/artiom/Terminator/models/text8')

# train the skip-gram model; default window=5
model = word2vec.Word2Vec(sentences, size=200)

# ... and some hours later... just as advertised...
print(model.most_similar(positive=['woman', 'king'], negative=['man'], topn=1))
# Out:
# 2017-10-13 22:26:26,412 : INFO : collecting all words and their counts
# 2017-10-13 22:26:26,511 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-10-13 22:26:35,006 : INFO : collected 253854 word types from a corpus of 17005207 raw words and 1701 sentences
# 2017-10-13 22:26:35,007 : INFO : Loading a fresh vocabulary
# 2017-10-13 22:26:35,544 : INFO : min_count=5 retains 71290 unique words (28% of original 253854, drops 182564)
# 2017-10-13 22:26:35,545 : INFO : min_count=5 leaves 16718844 word corpus (98% of original 17005207, drops 286363)
# 2017-10-13 22:26:36,053 : INFO : deleting the raw counts dictionary of 253854 items
# 2017-10-13 22:26:36,090 : INFO : sample=0.001 downsamples 38 most-common words
# 2017-10-13 22:26:36,093 : INFO : downsampling leaves estimated 12506280 word corpus (74.8% of prior 16718844)
# 2017-10-13 22:26:36,095 : INFO : estimated required memory for 71290 words and 200 dimensions: 149709000 bytes
# ...

# %%
print(model.most_similar(positive=['woman', 'king'], negative=['man'], topn=1))
# Out:
# [('queen', 0.6439793109893799)]

# %%
print(model.most_similar(positive=['country', "king"], negative=['queen'], topn=1))
# Out:
# [('nation', 0.5128435492515564)]

# %%
model.n_similarity("russia", "england")
# Out:
# 0.44075837422077735

# %%
model.save('/media/artiom/Terminator/models/gensim_word2vec_model.pickle')
# Out:
# 2017-10-13 14:05:36,590 : INFO : saving Word2Vec object under /media/artiom/Terminator/models/gensim_word2vec_model.pickle, separately None
# 2017-10-13 14:05:36,594 : INFO : not storing attribute syn0norm
# 2017-10-13 14:05:36,597 : INFO : storing np array 'syn0' to /media/artiom/Terminator/models/gensim_word2vec_model.pickle.wv.syn0.npy
# 2017-10-13 14:05:37,105 : INFO : storing np array 'syn1neg' to /media/artiom/Terminator/models/gensim_word2vec_model.pickle.syn1neg.npy
# 2017-10-13 14:05:37,742 : INFO : not storing attribute cum_table
# 2017-10-13 14:05:38,152 : INFO : saved /media/artiom/Terminator/models/gensim_word2vec_model.pickle
