# %%
import pandas as pd
from collections import Counter
import functools
import tqdm
import re
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier

# %%
dftrain, dftest = pd.read_csv("../train_task1_latest.csv"), pd.read_csv("../test_task1_latest.csv")

# %%
dftrain
# Out:
#         paragraph_id  question_id  \
# 0               1094        46273
# 1               7414        19164
# 2               6744        39767
# 3               7300        36318
# 4               7077        41534
# 5               3559        62585
# 6               4350         3730
# 7               8012        86629
# 8               3634        69421
# 9               4350        27335
# 10              1436        21441
# 11               949        51239
# 12              4817        54121
# 13              3489        43748
# 14              5156        87209
# 15              7814        28531
# 16              2270        78977
# 17              5116        59287
# 18               254        87786
# 19              7990        36305
# 20              1646        44327
# 21              3726        12085
# 22              3614        13550
# 23              5373        82357
# 24              6193        62697
# 25              1898        99146
# 26              1957        70656
# 27               242        41701
# 28               959        63850
# 29              8461        30985
# ...              ...          ...
# 119368          3167          113
# 119369          8969        83004
# 119370          4130        66375
# 119371           949        18147
# 119372          5841        68517
# 119373          6193        70518
# 119374           882        93725
# 119375          1898        52885
# 119376          8377        30232
# 119377          7183        88645
# 119378          4205        24854
# 119379           949        41227
# 119380          7719        45002
# 119381          1494        34573
# 119382          1867       100451
# 119383          1957        26879
# 119384          3553        38140
# 119385          7174        76720
# 119386          5612        52408
# 119387          8941        52337
# 119388          4076        12347
# 119389          5116        36648
# 119390          5690        14434
# 119391          6193        19600
# 119392          3726        89623
# 119393           787        78704
# 119394          7414        97752
# 119395          3845         2104
# 119396           168        92509
# 119397          2679        41770
#
#                                                 paragraph  \
# 0       В отличие от рыб, земноводные (амфибии) и прес...
# 1       В 1049 году Балдуину V удалось отнять у Герман...
# 2       Стремление достичь предельных значений ёмкости...
# 3       Первый практически пригодный двухтактный газов...
# 4       Требуя от художника углубленного изучения изоб...
# 5       Белки — высокомолекулярные органические вещест...
# 6       Прайсинговые методы — в основе лежит принцип и...
# 7       Применяли изначально для определения близкород...
# 8       Успешная конверсия по-разному определяется гру...
# 9       Прайсинговые методы — в основе лежит принцип и...
# 10      Относительно нормативности использовании терми...
# 11      1980-е годы для Спилберга были своего рода пло...
# 12      Первым романтическим увлечением юного Тургенев...
# 13      После Платона и Аристотеля в Греции, а затем в...
# 14      В древности разум традиционно связывался с бла...
# 15      Сразу после возвращения Фрама Нансен стал глав...
# 16      Из российских и советских актёров ролями в амп...
# 17      Отец Ивана Сергей Николаевич Тургенев (1793—18...
# 18      В древнегреческой мысли монотеистическая идея ...
# 19      В СССР бытовые магнитофоны стали широко доступ...
# 20      Рязанская земля одна из древнейших территорий ...
# 21      Из войны буффонов родилась французская комичес...
# 22      Согласно легенде, греческий воин по имени Фиди...
# 23      В 1896—1901 гг в Благовещенске был построен же...
# 24      В течение десятилетий имя Бунина часто упомина...
# 25      В июле 1980 года ВКНВ запретил рабство. Маврит...
# 26      На 4-м канале Британского телевидения с 1998 г...
# 27      О Шопене глубоко скорбел весь музыкальный мир....
# 28      Замысел романа Жизнь Арсеньева — книги, повлия...
# 24      Какого числа в 1945 году Мемель был освобождён...     0.0
# 25      Что доказал успех произведений, где действие р...     0.0
# 26      Что привело к почти полному переходу кинопроиз...     0.0
# 27                         Где похоронен Фредерик Шопена?     1.0
# 28      В канун какого события у И.А.Бунина появился з...     1.0
# 29      Что может привести к ситуации, когда изменивши...     0.0
# ...                                                   ...     ...
# 119368                                 Что такое закалка?     1.0
# 119369  В какой форме наблюдается половой процесс у не...     0.0
# 119370  Что не возникает между материнским организмом ...     0.0
# 119371  В каком году было возрождено название Carte Bl...     0.0
# 119372  Чем отличаются патроны к автоматическим авиаци...     1.0
# 119373  Что произошло в лихие 90-е годы с тяжелой пром...     0.0
# 119374  Могли ли дети такого возраста быть принесены в...     1.0
# 119375  чем, например, может объясняться то, что бабоч...     0.0
# 119376  Назовите однополосную компандерную систему шум...     1.0
# 119377  Как звали микробиолога, который в 1884 году в ...     0.0
# 119378  Что в правах исходило из религиозных норм и бы...     0.0
# 119379  Что можно было сделать в примитивных механичес...     0.0
# 119380  Куда поступает кровь через лёгочный клапан и л...     0.0
# 119381  Под эгидой кого была учреждена Международная м...     1.0
# 119382  У каких видов к заботе о подрастающем потомств...     0.0
# 119383  В каком году были описаны морские мины с длинн...     0.0
# 119384  Где продолжили работу группы специалистов по и...     1.0
# 119385           В какой период Северные особи мигрируют?     1.0
# 119386  Чью музыку на западе иногда используют как фон...     0.0
# 119387  Кто подал депутатский запрос в Генеральную Про...     0.0
# 119388  Функция организации — это формирование структу...     0.0
# 119389  В образе чего предполагается использовать инос...     0.0
# 119390  Какое соотношение ширины и высоты (горизонталь...     0.0
# 119391  На что инфант испанский Карл, поменял Парму и ...     0.0
# 119392  В каких магнитофонах нередко предусмотрено спе...     0.0
# 119393  Какие новые спортивные сооружения были построе...     0.0
# 119394                      В каком году умер Райан Уайт?     0.0
# 119395  Когда на всемирном конгрессе немецких школ за ...     0.0
# 119396  Что в конце 1940-х — начале 1950-х годов разра...     0.0
# 119397  с каким персонажем происходит схватка Шерлока ...     0.0
#
# [119398 rows x 5 columns]

# %%
dftrain.ix[10,'paragraph']
# Out:
# 'Относительно нормативности использовании термина в форме пиксел либо пиксель имеются различные мнения. Так Русский орфографический словарь РАН [4] квалифицирует форму пиксел как общеупотребительную, а форму пиксель как характерную разговорной профессиональной или разговорной и профессиональной речи (в сокращениях словаря нет расшифровки для разг. проф. речи, но есть отдельно разг. — разговорное, проф. — профессиональное[5]; однозначной расшифровки этого определения не даёт и справочная служба русского языка на портале Грамота.ру[6]). С другой стороны, действующий ГОСТ 27459-87[7] предусматривает термин пиксель как единственно возможный для использования в области применения указанного стандарта (компьютерная графика) и который является обязательным для применения в документации и литературе всех видов, входящих в сферу действия стандартизации или использующих результаты этой деятельности . При этом ГОСТ 27459-87 под термином пиксель понимает наименьший элемент поверхности визуализации, которому может быть независимым образом заданы цвет, интенсивность и другие характеристики изображения .'

# %%
@functools.lru_cache(maxsize=2 ** 19)
def uniq_words(text):
    # Очевидно это все уникальные слова без учета форм
    return set(re.findall("\w+", text))

def calculate_idfs(data):
    counter_paragraph = Counter()
    # Это явно все уникальные параграфы
    uniq_paragraphs = data['paragraph'].unique()
    for paragraph in tqdm.tqdm(uniq_paragraphs, desc="calc idf"):
        set_words = uniq_words(paragraph)
        counter_paragraph.update(set_words)
        
    num_docs = uniq_paragraphs.shape[0]
    idfs = {}
    for word in counter_paragraph:
        idfs[word] = np.log(num_docs / counter_paragraph[word])
    return idfs

# %%
idfs = calculate_idfs(dftrain)
# Out:
# calc idf: 100%|██████████| 9078/9078 [00:02<00:00, 4368.86it/s]

# %%
# Расчет фич занял 30 минут!
for name, df in [('train', dftrain), ('test', dftest)]:
    for index, row in tqdm.tqdm(df.iterrows(), total=df.shape[0], desc="build features for " + name):
        question = uniq_words(row.question)
        paragraph = uniq_words(row.paragraph)
        df.loc[index, 'len_paragraph'] = len(paragraph)
        df.loc[index, 'len_question'] = len(question)
        df.loc[index, 'len_intersection'] = len(paragraph & question)
        df.loc[index, 'idf_question'] = np.sum([idfs.get(word, 0.0) for word in question])
        df.loc[index, 'idf_paragraph'] = np.sum([idfs.get(word, 0.0) for word in paragraph])
        df.loc[index, 'idf_intersection'] = np.sum([idfs.get(word, 0.0) for word in paragraph & question])
# Out:
# build features for train: 100%|██████████| 119398/119398 [26:11<00:00, 75.98it/s]
# build features for test: 100%|██████████| 74294/74294 [12:02<00:00, 102.86it/s]

# %%
dftrain.head()
# Out:
#    paragraph_id  question_id  \
# 0          5551        56724
# 1          6678        64727
# 2          5941        56747
# 3          2075        50763
# 4          5204        53421
#
#                                            paragraph  \
# 0  31 августа 2016 года АО Банк Финсервис получил...
# 1  Лимфатическая система выступает как дополнение...
# 2  Тиристорно-импульсная система управления (ТИСУ...
# 3  После начала борьбы с православием в Литовском...
# 4  В 1954 году Шостакович писал: Дисциплина труда...
#
#                                             question  target  len_paragraph  \
# 0  Кто подтвердил рейтинг кредитоспособности ПАО ...     0.0           65.0
# 1  Какое положение между одиночным и стадным обра...     0.0           70.0
# 2      Чем не создается необходимый по величине ток?     1.0           71.0
# 3  В какой части города многочисленны пруды, обра...     0.0           95.0
# 4  К какой культуре по мнению Шнитке принадлежали...     0.0          109.0
#
#    len_question  len_intersection  idf_question  idf_paragraph  \
# 0          17.0               3.0     83.650717     320.188531
# 1          13.0               4.0     64.781264     382.531147
# 2           7.0               5.0     32.478578     389.340211
# 3          13.0               3.0     63.039527     532.465918
# 4          10.0               3.0     43.181146     538.020191
#
#    idf_intersection
# 0          1.446893
# 1          9.737011
# 2         20.286093
# 3          1.712881
# 4         11.646477

# %%
# Обучение заняло 30 сек
columns = ['len_paragraph', 'len_question', 'len_intersection', 'idf_question', 'idf_paragraph', 'idf_intersection']
model = GradientBoostingClassifier().fit(dftrain[columns], dftrain['target'])
dftest['prediction'] = model.predict_proba(dftest[columns])[:, 1]

# %%
dftest[['paragraph_id', 'question_id', 'prediction']].to_csv("prediction2.csv", index=False)
